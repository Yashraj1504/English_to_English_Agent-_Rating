# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashraj1504/English_to_English_Agent-_Rating/blob/main/S_D_with_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install assemblyai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import assemblyai as aai
import os

# Set your API key
aai.settings.api_key = "295cbc3589c7408ca09232c6642f531d"

# Define the path to the sample data folder
audio_folder = "/content/sample_data"

# List all audio files in the folder (you can filter by extensions like .mp3 or .wav)
audio_files = [f for f in os.listdir(audio_folder) if f.endswith('.mp3')]

# Define the transcription config
config = aai.TranscriptionConfig(
    speaker_labels=True,
    speakers_expected=2,
    language_code="en"
)

# Loop through each file and transcribe it
for audio_file in audio_files:
    audio_url = os.path.join(audio_folder, audio_file)

    # Transcribe the audio
    transcript = aai.Transcriber().transcribe(audio_url, config)

    print(f"Transcription for {audio_file}:\n")

    # Print out the transcript with speaker labels
    for utterance in transcript.utterances:
        print(f"Speaker {utterance.speaker}: {utterance.text}")

    print("\n" + "-"*50 + "\n")  # Add a separator between transcriptions
# Out:
# Transcription for OUTBOUNDSAMPLE_01.mp3:
#
# Speaker A: Hello? May I, please, Anthony.
# Speaker B: Hello, this is Anthony.
# Speaker A: Hi, Anthony. My name is Jeff, and I'm calling on behalf of education experts from a quality monitored line. And I see here that you recently filled a form on the Internet indicating an interest in earning a degree.
# Speaker B: Yes.
# Speaker A: Correct?
# Speaker B: Yes.
# Speaker A: I only need a few moments of your time to match the most appropriate schools. Are you at least 18 years of age?
# Speaker B: Yeah, I'm 29.
# Speaker A: 29. Okay. And do you currently have a high school diploma or a ged?
# Speaker B: Yes, I do.
# Speaker A: Okay, thank you, Anthony. And if we can find a school for you that meets your needs, would you be interested in furthering your education in the next six months? Yeah, of course.
# Speaker B: The course I'd like to take up would be computer engineering.
# ...

# %%
import assemblyai as aai
import os
import json

# Set your API key
aai.settings.api_key = "295cbc3589c7408ca09232c6642f531d"

# Define the path to the sample data folder
audio_folder = "/content/sample_data"

# List all audio files in the folder (you can filter by extensions like .mp3 or .wav)
audio_files = [f for f in os.listdir(audio_folder) if f.endswith('.mp3')]

# Define the transcription config
config = aai.TranscriptionConfig(
    speaker_labels=True,
    speakers_expected=2,
    language_code="en"
)

# Dictionary to store transcriptions
transcriptions_dict = {}

# Loop through each file and transcribe it
for audio_file in audio_files:
    audio_url = os.path.join(audio_folder, audio_file)

    # Transcribe the audio
    transcript = aai.Transcriber().transcribe(audio_url, config)

    print(f"Transcription for {audio_file}:\n")

    # Store transcript in dictionary
    transcriptions_dict[audio_file] = [
        {"speaker": utterance.speaker, "text": utterance.text}
        for utterance in transcript.utterances
    ]

    # Print out the transcript with speaker labels
    for utterance in transcript.utterances:
        print(f"Speaker {utterance.speaker}: {utterance.text}")

    print("\n" + "-" * 50 + "\n")  # Add a separator between transcriptions

# Save the transcriptions dictionary to a JSON file
output_file = "transcriptions.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(transcriptions_dict, f, indent=4, ensure_ascii=False)

print(f"Transcriptions saved to {output_file}")
# Out:
# Transcription for OUTBOUNDSAMPLE_01.mp3:
#
# Speaker A: Hello? May I, please, Anthony.
# Speaker B: Hello, this is Anthony.
# Speaker A: Hi, Anthony. My name is Jeff, and I'm calling on behalf of education experts from a quality monitored line. And I see here that you recently filled a form on the Internet indicating an interest in earning a degree.
# Speaker B: Yes.
# Speaker A: Correct?
# Speaker B: Yes.
# Speaker A: I only need a few moments of your time to match the most appropriate schools. Are you at least 18 years of age?
# Speaker B: Yeah, I'm 29.
# Speaker A: 29. Okay. And do you currently have a high school diploma or a ged?
# Speaker B: Yes, I do.
# Speaker A: Okay, thank you, Anthony. And if we can find a school for you that meets your needs, would you be interested in furthering your education in the next six months? Yeah, of course.
# Speaker B: The course I'd like to take up would be computer engineering.
# ...

# %%
pip install requests

# %%
# !pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile" ,       # groq model
    temperature=0.1,                        # it's mention randomness in result after maximum times asking
    max_tokens=None,                        # unit of words you wants to generate , here none means the generate no. of words like upto your limitations
    timeout=None,                           # maximum time to wait for the model responce
    max_retries=2,                          # no. of attempts , after 2 attempts its gives error bcz here limitation is 2
    api_key="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" # this ensures that only authorised user can interact with the groq language model

)

# %%
messages = [
    (
        "system",
        "You are an AI that classifies speakers in a conversation as either 'Client' or 'Agent'. "
        "A Client asks for information or makes requests, while an Agent provides answers or handles requests."
        "Also give the separately Agent rating out of 10 on client and agent conversation and also agent behaviour or responce on client question . and only give in few words and also give this agent behaviour for his each respective sentence."
    ),
    (
        "human",
        output_file

    ),
]

ai_msg = llm.invoke(messages)  # Invoke LLM API to classify speakers
print(ai_msg.content)
# Out:
# No conversation provided.

# %%
import assemblyai as aai
import os
import json

# Set your API key
aai.settings.api_key = "295cbc3589c7408ca09232c6642f531d"

# Define the path to the sample data folder
audio_folder = "/content/sample_data"

# List all audio files in the folder (supports .mp3 and .wav)
audio_files = [f for f in os.listdir(audio_folder) if f.endswith(('.mp3', '.wav'))]

# Define the transcription config
config = aai.TranscriptionConfig(
    speaker_labels=True,
    speakers_expected=2,
    language_code="en"
)

# Dictionary to store transcriptions
transcriptions_dict = {}

# Loop through each file and transcribe it
for audio_file in audio_files:
    audio_url = os.path.join(audio_folder, audio_file)

    # Transcribe the audio
    transcript = aai.Transcriber().transcribe(audio_url, config)

    print(f"Transcription for {audio_file}:\n")

    # Store transcript in dictionary
    transcriptions_dict[audio_file] = [
        {"speaker": utterance.speaker, "text": utterance.text}
        for utterance in transcript.utterances
    ]

    # Print out the transcript with speaker labels
    for utterance in transcript.utterances:
        print(f"Speaker {utterance.speaker}: {utterance.text}")

    print("\n" + "-" * 50 + "\n")  # Add a separator between transcriptions

# Save the transcriptions dictionary to a JSON file
output_file = "transcriptions.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(transcriptions_dict, f, indent=4, ensure_ascii=False)

print(f"Transcriptions saved to {output_file}")


# Read the JSON file
with open(output_file, "r", encoding="utf-8") as f:
    transcription_data = json.load(f)

# Convert transcription into formatted conversation text
conversation_text = ""
for audio_file, utterances in transcription_data.items():
    for utt in utterances:
        conversation_text += f"Speaker {utt['speaker']}: {utt['text']}\n"

# Define the messages for the LLM
messages = [
    (
        "system",
        "You are an AI that classifies speakers in a conversation as either 'Client' or 'Agent'. "
        "A Client asks for information or makes requests, while an Agent provides answers or handles requests. "
        "Also give separately an Agent rating out of 10 on client-agent conversation and analyze the agent's behavior "
        "for each respective sentence in a few words."
    ),
    (
        "human",
        conversation_text  # Pass the formatted transcription data
    ),
]

# Invoke the LLM API to classify speakers
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Transcription for OUTBOUNDSAMPLE_01.mp3:
#
# Speaker A: Hello? May I, please, Anthony.
# Speaker B: Hello, this is Anthony.
# Speaker A: Hi, Anthony. My name is Jeff, and I'm calling on behalf of education experts from a quality monitored line. And I see here that you recently filled a form on the Internet indicating an interest in earning a degree.
# Speaker B: Yes.
# Speaker A: Correct?
# Speaker B: Yes.
# Speaker A: I only need a few moments of your time to match the most appropriate schools. Are you at least 18 years of age?
# Speaker B: Yeah, I'm 29.
# Speaker A: 29. Okay. And do you currently have a high school diploma or a ged?
# Speaker B: Yes, I do.
# Speaker A: Okay, thank you, Anthony. And if we can find a school for you that meets your needs, would you be interested in furthering your education in the next six months? Yeah, of course.
# Speaker B: The course I'd like to take up would be computer engineering.
# ...

# %%
import assemblyai as aai
import os
import json

# Set your API key
aai.settings.api_key = "295cbc3589c7408ca09232c6642f531d"

# Define the path to the sample data folder
audio_folder = "/content/sample_data/OUTBOUNDSAMPLE_01.mp3"

# List all audio files in the folder (supports .mp3 and .wav)
audio_files = [f for f in os.listdir(audio_folder) if f.endswith(('.mp3', '.wav'))]

# Define the transcription config
config = aai.TranscriptionConfig(
    speaker_labels=True,
    speakers_expected=2,
    language_code="en"
)

# Dictionary to store transcriptions
transcriptions_dict = {}

# Loop through each file and transcribe it
for audio_file in audio_files:
    audio_url = os.path.join(audio_folder, audio_file)

    # Transcribe the audio
    transcript = aai.Transcriber().transcribe(audio_url, config)

    print(f"Transcription for {audio_file}:\n")

    # Store transcript in dictionary
    transcriptions_dict[audio_file] = [
        {"speaker": utterance.speaker, "text": utterance.text}
        for utterance in transcript.utterances
    ]

    # Print out the transcript with speaker labels
    for utterance in transcript.utterances:
        print(f"Speaker {utterance.speaker}: {utterance.text}")

    print("\n" + "-" * 50 + "\n")  # Add a separator between transcriptions

# Save the transcriptions dictionary to a JSON file
output_file = "transcriptions.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(transcriptions_dict, f, indent=4, ensure_ascii=False)

print(f"Transcriptions saved to {output_file}")


# Read the JSON file
with open(output_file, "r", encoding="utf-8") as f:
    transcription_data = json.load(f)

# Convert transcription into formatted conversation text
conversation_text = ""
for audio_file, utterances in transcription_data.items():
    for utt in utterances:
        conversation_text += f"Speaker {utt['speaker']}: {utt['text']}\n"

# Define the messages for the LLM
messages = [
    (
        "system",
        "You are an AI that classifies speakers in a conversation as either 'Client' or 'Agent'. "
        "A Client asks for information or makes requests, while an Agent provides answers or handles requests. "
        "Also give separately an Agent rating out of 10 on client-agent conversation and analyze the agent's behavior "
        "for each respective sentence in a few words."
    ),
    (
        "human",
        conversation_text  # Pass the formatted transcription data
    ),
]

# Invoke the LLM API to classify speakers
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-33-1a6e1d8f2ad4> in <cell line: 0>()
#      10
#      11 # List all audio files in the folder (supports .mp3 and .wav)
# ---> 12 audio_files = [f for f in os.listdir(audio_folder) if f.endswith(('.mp3', '.wav'))]
#      13
#      14 # Define the transcription config
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/sample_data/OUTBOUNDSAMPLE_01.mp3'

# %%
import assemblyai as aai
import os
import json

# Set your API key
aai.settings.api_key = "295cbc3589c7408ca09232c6642f531d"

# Define the path to the sample data folder
audio_folder = "/content/sample_data"

# List all audio files in the folder (supports .mp3 and .wav)
audio_files = [f for f in os.listdir(audio_folder) if f.endswith(('.mp3', '.wav'))]

# Define the transcription config
config = aai.TranscriptionConfig(
    speaker_labels=True,
    speakers_expected=2,
    language_code="en"
)

# Dictionary to store transcriptions
transcriptions_dict = {}

# Loop through each file and transcribe it
for audio_file in audio_files:
    audio_url = os.path.join(audio_folder, audio_file)

    # Transcribe the audio
    transcript = aai.Transcriber().transcribe(audio_url, config)

    print(f"Transcription for {audio_file}:\n")

    # Store transcript in dictionary
    transcriptions_dict[audio_file] = [
        {"speaker": utterance.speaker, "text": utterance.text}
        for utterance in transcript.utterances
    ]

    # Print out the transcript with speaker labels
    for utterance in transcript.utterances:
        print(f"Speaker {utterance.speaker}: {utterance.text}")

    print("\n" + "-" * 50 + "\n")  # Add a separator between transcriptions

# Save the transcriptions dictionary to a JSON file
output_file = "transcriptions.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(transcriptions_dict, f, indent=4, ensure_ascii=False)

print(f"Transcriptions saved to {output_file}")


# Read the JSON file
with open(output_file, "r", encoding="utf-8") as f:
    transcription_data = json.load(f)

# Convert transcription into formatted conversation text
conversation_text = ""
for audio_file, utterances in transcription_data.items():
    for utt in utterances:
        conversation_text += f"Speaker {utt['speaker']}: {utt['text']}\n"

# Define the messages for the LLM
messages = [
    (
        "system",
        "You are an AI that classifies speakers in a conversation as either 'Client' or 'Agent'. "
        "A Client asks for information or makes requests, while an Agent provides answers or handles requests. "
        "Also give separately an Agent rating out of 10 on client-agent conversation and analyze the agent's behavior "
        "for each respective sentence in a few words."
        "Please tell me on which basis they give rating out of 10 to the agent"
    ),
    (
        "human",
        conversation_text  # Pass the formatted transcription data
    ),
]

# Invoke the LLM API to classify speakers
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Transcription for OUTBOUNDSAMPLE_01.mp3:
#
# Speaker A: Hello? May I, please, Anthony.
# Speaker B: Hello, this is Anthony.
# Speaker A: Hi, Anthony. My name is Jeff, and I'm calling on behalf of education experts from a quality monitored line. And I see here that you recently filled a form on the Internet indicating an interest in earning a degree.
# Speaker B: Yes.
# Speaker A: Correct?
# Speaker B: Yes.
# Speaker A: I only need a few moments of your time to match the most appropriate schools. Are you at least 18 years of age?
# Speaker B: Yeah, I'm 29.
# Speaker A: 29. Okay. And do you currently have a high school diploma or a ged?
# Speaker B: Yes, I do.
# Speaker A: Okay, thank you, Anthony. And if we can find a school for you that meets your needs, would you be interested in furthering your education in the next six months? Yeah, of course.
# Speaker B: The course I'd like to take up would be computer engineering.
# ...

# %%
messages = [
    (
        "system",
         "You are an AI that performs transliteration, converting English words into Marathi script "
        "without translating them. Preserve the original pronunciation as much as possible."
    ),
    (
        "human",
        "ai_msg content"

    ),
]

ai_msg = llm.invoke(messages)  # Invoke LLM API to classify speakers
print(ai_msg.content)
# Out:
# एआय_मेसेज कंटेंट

# %%
import assemblyai as aai
import os
import json

# Set your API key
aai.settings.api_key = "295cbc3589c7408ca09232c6642f531d"

# Specify the single audio file path (update this with your file path)
audio_file = "/content/sample_data/OUTBOUNDSAMPLE_01.mp3"  # Change this to your file path

# Ensure the file exists before proceeding
if not os.path.exists(audio_file):
    raise FileNotFoundError(f"File not found: {audio_file}")

# Define the transcription config
config = aai.TranscriptionConfig(
    speaker_labels=True,
    speakers_expected=2,
    language_code="en"
)

# Transcribe the single audio file
transcript = aai.Transcriber().transcribe(audio_file, config)

# Store transcript in dictionary
transcriptions_dict = {
    os.path.basename(audio_file): [
        {"speaker": utterance.speaker, "text": utterance.text}
        for utterance in transcript.utterances
    ]
}

# Print the transcription with speaker labels
print(f"Transcription for {audio_file}:\n")
for utterance in transcript.utterances:
    print(f"Speaker {utterance.speaker}: {utterance.text}")

print("\n" + "-" * 50 + "\n")

# Save the transcription to a JSON file
output_file = "transcription.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(transcriptions_dict, f, indent=4, ensure_ascii=False)

print(f"Transcription saved to {output_file}")

# Read the JSON file
with open(output_file, "r", encoding="utf-8") as f:
    transcription_data = json.load(f)

# Convert transcription into formatted conversation text
conversation_text = ""
for utt in transcription_data[os.path.basename(audio_file)]:
    conversation_text += f"Speaker {utt['speaker']}: {utt['text']}\n"

# Define the messages for the LLM
messages = [
    (
        "system",
        "You are an AI that classifies speakers in a conversation as either 'Client' or 'Agent'. "
        "A Client asks for information or makes requests, while an Agent provides answers or handles requests. "
        "Also give separately an Agent rating out of 10 on client-agent conversation and analyze the agent's behavior "
        "for each respective sentence in a few words."
        "Please tell me on which basis they give rating out of 10 to the agent"
    ),
    (
        "human",
        conversation_text  # Pass the formatted transcription data
    ),
]

# Invoke the LLM API to classify speakers
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Transcription for /content/sample_data/OUTBOUNDSAMPLE_01.mp3:
#
# Speaker A: Hello? May I, please, Anthony.
# Speaker B: Hello, this is Anthony.
# Speaker A: Hi, Anthony. My name is Jeff, and I'm calling on behalf of education experts from a quality monitored line. And I see here that you recently filled a form on the Internet indicating an interest in earning a degree.
# Speaker B: Yes.
# Speaker A: Correct?
# Speaker B: Yes.
# Speaker A: I only need a few moments of your time to match the most appropriate schools. Are you at least 18 years of age?
# Speaker B: Yeah, I'm 29.
# Speaker A: 29. Okay. And do you currently have a high school diploma or a ged?
# Speaker B: Yes, I do.
# Speaker A: Okay, thank you, Anthony. And if we can find a school for you that meets your needs, would you be interested in furthering your education in the next six months? Yeah, of course.
# Speaker B: The course I'd like to take up would be computer engineering.
# ...
